# %%
import requests,json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Functions for getting SensorTower data. 
# App_Intelligence
# Rate Limit: 6 requests per second. 
# Requests should be made to the following base URL, followed by the specific path to the API you want to use.
# Latest Updated Date: 2021.03.02
# Author: Chen


# Search Apps & Publishers (Retrieves App or Publisher data.)
# Input: 
# os: Operating System (use "ios" or "android")
# entity_type: App or Publisher (use "app" or "android")
# term: key word.Match an app name or publisher name(Minimum Characters: 2 non-Latin or 3 Latin) 
# limit: Limit how many apps returned per call (Max: 250)


# Output:

# Example: 
# https://api.sensortower-china.com:443/v1/ios/search_entities?entity_type=app&term=Among us&limit=25&auth_token=r7cTTJq5nBSqxMU_WmJo
# test_AppPub = requests_Search_Apps_Publishers('ios', 'app', 'Among Us', '25')  searching app 
# test_AppPub = requests_Search_Apps_Publishers('ios', 'publisher', 'Voo', '25') searching publisher



def requests_Search_Apps_Publishers(os, entity, term, limit):
    aux_info_AppPub = requests.get('https://api.sensortower-china.com/v1/'
                               +os+'/search_entities?entity_type='+entity+
                               '&term='+term+
                               '&limit='+limit+
                               '&auth_token=r7cTTJq5nBSqxMU_WmJo'
                                   )
    
    df_info_AppPub = pd.DataFrame(aux_info_AppPub.json())
    print(aux_info_AppPub.status_code) # Get response messages
    return(df_info_AppPub)
    
    
# Publisher (Retrieves a collection of Apps for the specified Publisher.)
# Input: 
# os: Operating System (use "ios" or "android")
# publisher_id: Fetches apps for a given Publisher.
# limit: Limits number of apps returned per call. Max 100 apps per call.
# Include_count: Includes count of publisher apps in response payload. Note: setting this to true changes the output structure of the API response. ???

# Output:

# Example: 
# https://api.sensortower-china.com/v1/ios/publisher/publisher_apps?publisher_id=714804730&limit=20&include_count=false&auth_token=r7cTTJq5nBSqxMU_WmJo
# test_Publishers1 = requests_Publishers('ios', '714804730','20')


def requests_Publishers(os, publisher_id, limit, include_count = 'false'):
    aux_info_publisher = requests.get('https://api.sensortower-china.com/v1/'
                                      +os+'/publisher/publisher_apps?publisher_id='+publisher_id+
                                      '&limit='+limit+
                                      '&include_count='+include_count+
                                      '&auth_token=r7cTTJq5nBSqxMU_WmJo'
                                     )
    
    df_info_publisher = pd.DataFrame(aux_info_publisher.json())
    print(aux_info_publisher.status_code) # Get response messages
    return(df_info_publisher)



# Apps

# Get apps (Retrieve app metadata, such as app name, publisher, categories, description, screenshots, rating, etc.)

# Input: 
# os: Operating System (use "ios" or "android")
# app_ids: Product ID for iOS. package name for Android,  

# Output:


# Example: 
# https://api.sensortower-china.com:443/v1/ios/apps?app_ids=284882215&country=US&auth_token=r7cTTJq5nBSqxMU_WmJo
# test_Apps1 = requests_Apps('ios', '1482766542','US')
# test_Apps2 = requests_Apps('android', 'com.innersloth.spacemafia','US')
# test_Apps3 = requests_Apps('ios', '1482766542,1351168404','US') 批量处理

def requests_Apps(os, app_ids, country):
    aux_info_Apps = requests.get('https://api.sensortower-china.com/v1/'
                                 +os+'/apps?app_ids='+app_ids+
                                 '&country='+country+
                                 '&auth_token=r7cTTJq5nBSqxMU_WmJo'
                                )
    df_info_Apps = pd.DataFrame(aux_info_Apps.json())
    print(aux_info_Apps.status_code) # Get response messages
    return(df_info_Apps)

# %%
test_Apps3 = requests_Apps('ios', '1482766542,1351168404','US')
test_Apps1
# Out:
# 200
#                                                 apps
# 0  {'app_id': 1351168404, 'canonical_country': 'U...
# 1  {'app_id': 1482766542, 'canonical_country': 'U...

# %%
test_Apps1['apps'][0]
# Out:
# {'advisories': ['Infrequent/Mild Cartoon or Fantasy Violence',
#   'Infrequent/Mild Horror/Fear Themes'],
#  'app_id': 1351168404,
#  'app_view_url': '/ios/us/innersloth-llc/app/among-us/1351168404/',
#  'apple_watch_enabled': None,
#  'bundle_id': 'com.innersloth.amongus',
#  'canonical_country': 'US',
#  'categories': [6014, 7001, 7015],
#  'content_rating': '9+',
#  'description': 'Play online or over local WiFi with 4-10 players as you attempt to prep your spaceship for departure, but beware as one will be an impostor bent on killing everyone!\n\nCrewmates can win by completing all tasks or discovering and voting the impostor off the ship. \n\nThe Impostor can use sabotage to cause chaos, making for easier kills and better alibis.',
#  'eula_url': None,
#  'feature_graphic': None,
#  'global_rating_count': 1128375,
#  'humanized_name': 'Among Us!',
#  'humanized_worldwide_last_month_downloads': {'downloads': 4000000,
#   'downloads_rounded': 4,
#   'prefix': None,
#   'string': '4m',
#   'units': 'm'},
#  'humanized_worldwide_last_month_revenue': {'prefix': '$',
#   'revenue': 1000000,
#   'revenue_rounded': 1,
#   'string': '$1m',
#   'units': 'm'},
#  'icon_url': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/23/0f/6d/230f6ded-6c5c-c2f3-53f5-a95b784092aa/AppIcon-0-0-1x_U007emarketing-0-0-0-7-0-0-sRGB-0-0-0-GLES2_U002c0-512MB-85-220-0-0.png/150x150bb.png',
#  'imessage_enabled': None,
#  'imessage_icon': None,
#  'in_app_purchases': True,
#  'name': 'Among Us!',
#  'os': 'ios',
#  'permissions': None,
#  'price': 0.0,
#  'privacy_policy_url': 'http://www.innersloth.com/amongus/data.php',
#  'promo_text': '',
#  'publisher_address': None,
#  'publisher_country': 'US',
#  'publisher_email': None,
#  'publisher_id': 957995279,
#  'publisher_name': 'InnerSloth LLC',
#  'publisher_profile_url': '/ios/publisher/innersloth-llc/957995279',
#  'rating': 4.4577,
#  'rating_count': 477817,
#  'rating_count_for_current_version': 477817,
#  'rating_for_current_version': 4.4577,
#  'release_date': '2018-07-25T09:39:48Z',
#  'screenshot_urls': ['https://is4-ssl.mzstatic.com/image/thumb/Purple113/v4/73/1b/34/731b34b1-b808-f0fd-c69b-eeb9444572d2/pr_source.png/1000x462bb.png',
#   'https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/a8/98/0f/a8980f9d-e3ae-8c8b-eb63-87591bcd78ec/pr_source.png/1000x462bb.png',
#   'https://is4-ssl.mzstatic.com/image/thumb/Purple113/v4/63/05/28/630528c2-198d-1c15-e46b-93fc0ac308d8/pr_source.png/1000x462bb.png',
#   'https://is1-ssl.mzstatic.com/image/thumb/Purple113/v4/c6/7c/e1/c67ce184-3c87-5fe0-97e8-b39faa0d0afe/pr_source.png/1000x462bb.png',
#   'https://is3-ssl.mzstatic.com/image/thumb/Purple113/v4/a1/22/0b/a1220b55-203a-68c2-3fd1-65383460d71c/pr_source.png/1000x462bb.png'],
#  'short_description': None,
#  'subtitle': '',
#  'support_url': 'https://discord.gg/uHTugnh',
#  'tablet_screenshot_urls': ['https://is1-ssl.mzstatic.com/image/thumb/Purple113/v4/34/98/c1/3498c11c-d9b5-f5b8-cf0f-a831765f0525/mzl.rtqhcrne.png/552x414bb.png',
#   'https://is2-ssl.mzstatic.com/image/thumb/Purple123/v4/99/98/c9/9998c985-7f6b-4800-560a-fe53060dbc20/mzl.aqvdyozc.png/552x414bb.png',
#   'https://is5-ssl.mzstatic.com/image/thumb/Purple113/v4/e2/a0/90/e2a090d2-13a3-5eb2-179c-ea5489abc210/mzl.aslvwfpm.png/552x414bb.png'],
#  'unified_app_id': '5b2483b6c66f8810923556fc',
#  'updated_date': '2020-11-23T00:00:00Z',
#  'url': 'https://apps.apple.com/US/app/id1351168404?l=en',
#  'valid_countries': ['US',
#   'AU',
#   'CA',
#   'FR',
#   'DE',
#   'GB',
#   'IT',
#   'JP',
#   'KR',
#   'RU',
#   'DZ',
#   'AO',
#   'AR',
#   'AT',
#   'AZ',
#   'BH',
#   'BB',
#   'BY',
#   'BE',
#   'BM',
#   'BR',
#   'BG',
#   'CL',
#   'CO',
#   'CR',
#   'HR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'EC',
#   'EG',
#   'SV',
#   'FI',
#   'GH',
#   'GR',
#   'GT',
#   'HK',
#   'HU',
#   'IN',
#   'ID',
#   'IE',
#   'IL',
#   'KZ',
#   'KE',
#   'KW',
#   'LB',
#   'LT',
#   'LU',
#   'MO',
#   'MG',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NG',
#   'NO',
#   'OM',
#   'PK',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'QA',
#   'RO',
#   'SA',
#   'RS',
#   'SG',
#   'SK',
#   'SI',
#   'ZA',
#   'ES',
#   'LK',
#   'SE',
#   'CH',
#   'TW',
#   'TH',
#   'TN',
#   'TR',
#   'UA',
#   'AE',
#   'UY',
#   'UZ',
#   'VE',
#   'VN',
#   'BO',
#   'KH',
#   'EE',
#   'LV',
#   'NI',
#   'PY',
#   'AF',
#   'GE',
#   'IQ',
#   'LY',
#   'MA',
#   'MZ',
#   'MM',
#   'YE'],
#  'version': '2020.11.17',
#  'website_url': 'http://www.innersloth.com/gameAmongUs.html'}

# %%
test_Apps1['apps'][1]
# Out:
# {'advisories': ['Infrequent/Mild Simulated Gambling',
#   'Infrequent/Mild Realistic Violence',
#   'Infrequent/Mild Cartoon or Fantasy Violence',
#   'Infrequent/Mild Sexual Content and Nudity',
#   'Infrequent/Mild Medical/Treatment Information',
#   'Infrequent/Mild Horror/Fear Themes',
#   'Infrequent/Mild Mature/Suggestive Themes',
#   'Infrequent/Mild Alcohol, Tobacco, or Drug Use or References'],
#  'app_id': 1482766542,
#  'app_view_url': '/ios/us/voodoo/app/spiral-roll/1482766542/',
#  'apple_watch_enabled': None,
#  'bundle_id': 'com.Celltop.SpiralRoll',
#  'canonical_country': 'US',
#  'categories': [6014, 7001, 7013],
#  'content_rating': '12+',
#  'description': 'Dig wood to form spirals and use them to destroy obstacles ! \n\nHave Fun :)',
#  'eula_url': None,
#  'feature_graphic': None,
#  'global_rating_count': 514737,
#  'humanized_name': 'Spiral Roll',
#  'humanized_worldwide_last_month_downloads': {'downloads': 700000,
#   'downloads_rounded': 700,
#   'prefix': None,
#   'string': '700k',
#   'units': 'k'},
#  'humanized_worldwide_last_month_revenue': {'prefix': '< $',
#   'revenue': 1000,
#   'revenue_rounded': 5,
#   'string': '< $5k',
#   'units': 'k'},
#  'icon_url': 'https://is4-ssl.mzstatic.com/image/thumb/Purple114/v4/63/ce/8c/63ce8c4c-f69b-a56e-0ddc-f1795d2cef48/AppIcon-0-0-1x_U007emarketing-0-0-0-7-0-0-sRGB-0-0-0-GLES2_U002c0-512MB-85-220-0-0.png/150x150bb.png',
#  'imessage_enabled': None,
#  'imessage_icon': None,
#  'in_app_purchases': True,
#  'name': 'Spiral Roll',
#  'os': 'ios',
#  'permissions': None,
#  'price': 0.0,
#  'privacy_policy_url': 'https://www.voodoo.io/privacy',
#  'promo_text': '',
#  'publisher_address': None,
#  'publisher_country': 'France',
#  'publisher_email': None,
#  'publisher_id': 714804730,
#  'publisher_name': 'Voodoo',
#  'publisher_profile_url': '/ios/publisher/voodoo/714804730',
#  'rating': 4.53923,
#  'rating_count': 199550,
#  'rating_count_for_current_version': 199550,
#  'rating_for_current_version': 4.53923,
#  'release_date': '2020-01-14T19:06:06Z',
#  'screenshot_urls': ['https://is3-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/14/65/73/1465731e-743e-dbdb-96e1-08d52dec4768/bbcba5b6-ab42-44f8-88d9-805ace6d50fe_iPhoneX_1.jpg/462x1000bb.png',
#   'https://is2-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/51/6c/e4/516ce485-418e-706e-9f3b-84f5df49addc/b4bb06f6-517f-4c52-8e2a-871319bd41ca_iPhoneX_2.jpg/462x1000bb.png',
#   'https://is3-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/ee/2e/02/ee2e023a-9941-2925-daf0-cd2f3a1495c1/ba063425-12b0-4ecb-afbd-2fee271d12da_iPhoneX_3.jpg/462x1000bb.png',
#   'https://is5-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/53/4c/b6/534cb6db-fc12-f2b6-0176-f4bcc8d222d9/a4511a71-582e-455c-9da6-1a91c536b426_iPhoneX_5.jpg/462x1000bb.png',
#   'https://is5-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/f2/f4/dd/f2f4dd53-89bc-617d-2565-608c51cecfcd/384b9e14-ea9e-48b0-9fd2-538ef7c83329_iPhoneX_4.jpg/462x1000bb.png'],
#  'short_description': None,
#  'subtitle': 'ROLL IT !!!',
#  'support_url': 'https://www.voodoo.io',
#  'tablet_screenshot_urls': ['https://is3-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/92/b1/12/92b1122b-3381-214f-1f80-a4c010e883b5/df0ab3e3-d502-4810-a525-0eae0359cedf_iPad_1.jpg/576x768bb.jpg',
#   'https://is3-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/e2/ad/cc/e2adcc68-2287-2c69-cf2d-439fec08cc2d/49b97b7c-1bdf-4c81-9344-c13cefc81b50_iPad_2.jpg/576x768bb.jpg',
#   'https://is3-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/27/2b/52/272b524e-95f4-2dee-d933-5de0ea1278bb/5d301e41-0ada-43c4-ba66-34965ff07b2d_iPad_3.jpg/576x768bb.jpg',
#   'https://is5-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/3d/1c/63/3d1c63d0-4c84-4d56-963e-d7bbae0e816a/fda717a1-4e9e-40a9-af71-6012236ef020_iPad_5.jpg/576x768bb.jpg',
#   'https://is5-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/0e/06/8d/0e068ddb-9be1-043e-cdcb-82c4c3989a46/bd72a2f7-1c4c-4103-8520-7b6d6ec5b954_iPad_4.jpg/576x768bb.jpg'],
#  'unified_app_id': '5e1e1f8eb9ab944cf7f439e3',
#  'updated_date': '2020-12-02T00:00:00Z',
#  'url': 'https://apps.apple.com/US/app/id1482766542?l=en',
#  'valid_countries': ['US',
#   'AU',
#   'CA',
#   'FR',
#   'DE',
#   'GB',
#   'IT',
#   'JP',
#   'KR',
#   'RU',
#   'DZ',
#   'AO',
#   'AR',
#   'AT',
#   'AZ',
#   'BH',
#   'BB',
#   'BY',
#   'BE',
#   'BM',
#   'BR',
#   'BG',
#   'CL',
#   'CO',
#   'CR',
#   'HR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'EC',
#   'EG',
#   'SV',
#   'FI',
#   'GH',
#   'GR',
#   'GT',
#   'HK',
#   'HU',
#   'IN',
#   'ID',
#   'IE',
#   'IL',
#   'KZ',
#   'KE',
#   'KW',
#   'LB',
#   'LT',
#   'LU',
#   'MO',
#   'MG',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NG',
#   'NO',
#   'OM',
#   'PK',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'QA',
#   'RO',
#   'SA',
#   'RS',
#   'SG',
#   'SK',
#   'SI',
#   'ZA',
#   'ES',
#   'LK',
#   'SE',
#   'CH',
#   'TW',
#   'TH',
#   'TN',
#   'TR',
#   'UA',
#   'AE',
#   'UY',
#   'UZ',
#   'VE',
#   'VN',
#   'BO',
#   'KH',
#   'EE',
#   'LV',
#   'NI',
#   'PY',
#   'GE',
#   'IQ',
#   'LY',
#   'MA',
#   'MZ',
#   'MM',
#   'YE'],
#  'version': '1.11.0',
#  'website_url': 'https://www.voodoo.io'}
