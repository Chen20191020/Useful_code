# %%
import requests,json
import pandas as pd

# %%
ios_total = pd.read_excel('新总表.xlsx', sheet_name = '新iOS（含AA信息）')

# %%
# ios包名转换为string
ios_total['Package Name']=ios_total['Package Name'].apply(lambda x: str(int(x)) if str(x)!= 'nan' else x)

# %%
ios_total = ios_total[['Package Name','AA App Name','Unified App Name','Publisher Name']]
ios_total = ios_total[ios_total['Package Name'].notna()]
ios_total = ios_total.reset_index()

ios_total_string = ''
for i in ios_total['Package Name']:
    ios_total_string+=i+','
ios_total_string = ios_total_string[:-1]
# Out:
#       index Package Name  AA App Name  \
# 0         0   1351168404          NaN
# 1         1   1522899035          NaN
# 2         2   1533666452          NaN
# 3         3    985746746          NaN
# 4         4   1526638009          NaN
# ...     ...          ...          ...
# 2423   2701   1358671513          NaN
# 2424   2702   1439875940          NaN
# 2425   2703   1455494725          NaN
# 2426   2704   1438868372          NaN
# 2427   2705   1462576807          NaN
#
#                                        Unified App Name  \
# 0                                              Among Us
# 1                                          Chat Master!
# 2                                      Let's Be Cops 3D
# 3     Discord - Talk, Video Chat & Hang Out with Fri...
# 4                                        Acrylic Nails!
# ...                                                 ...
# 2423                                      Flying Arrow!
# ...

# %%
'''
This fnx is for obatining AA_ids(product_ids), of APPs, including its package_id and AA_ids. 
It mainly serves for the apps on google-play. (iOS package_id can be obatined by [1]).

    INPUTS:
        platform: ios/google-play
        package_ids: A string / Strings seperated by commas
    
    RETURN:
        A dataframe of package_ids and AA_ids that user obatained.
        
'''

def Packageid2AAid(platform,package_ids):
    r = requests.get('https://api.appannie.com/v1.3/apps/'+ platform+'/package-codes2ids?package_codes='+package_ids,
                 headers = {'Authorization':'bearer da420ceb1867f439bc7f3f64f21437749ba074a8'})
    return pd.DataFrame(r.json()['items'])

# %% [markdown]
# ## Android

# %%
android_total = pd.read_excel('新总表.xlsx', sheet_name = '新Android（含AA信息）')

# %%
android_total = android_total[['Package Name','AA App Name','Unified App Name','Publisher Name']]
android_total = android_total[android_total['Package Name'].notna()]
android_total = android_total.reset_index()
android_total
# Out:
#       index                                       Package Name  \
# 0         0                          com.innersloth.spacemafia
# 1         1                            com.RBSSOFT.HyperMobile
# 2         2                           com.ohmgames.cheatandrun
# 3         3                              com.kwalee.letsbecops
# 4         4                      com.orbitalknight.forcemaster
# 5         5              com.hyperdivestudio.papersgradeplease
# 6         6                                  com.roblox.client
# 7         7                              com.unicostudio.whois
# 8         8                                  com.foxbet.super6
# 9         9                                  com.idleants.game
# 10       10                          com.rollic.tanglemaster3D
# 11       11                                   com.isl.stairrun
# 12       12                           com.freeplay.runandfight
# 13       13                           com.zplay.carvethepencil
# ...

# %%
'''
android_name = pd.DataFrame()
for j in range((len(android_total)//150)+1):
    print(j)
    if j > 16:
        android_total_string = ''
        for i in android_total['Package Name'][17*150:]:
            android_total_string+=i+','
            android_total_string = android_total_string[:-1]
            temp_name = Packageid2AAid('google-play',android_total_string)
            android_name.append(temp_name)
        
    else:
        android_total_string = ''
        for i in android_total['Package Name'][j*150:(j+1)*150]:
            android_total_string+=i+','
            android_total_string = android_total_string[:-1]
            temp_name = Packageid2AAid('google-play',android_total_string)
            android_name.append(temp_name)

'''
# Out:
# "\nandroid_name = pd.DataFrame()\nfor j in range((len(android_total)//150)+1):\n    print(j)\n    if j > 16:\n        android_total_string = ''\n        for i in android_total['Package Name'][17*150:]:\n            android_total_string+=i+','\n            android_total_string = android_total_string[:-1]\n            temp_name = Packageid2AAid('google-play',android_total_string)\n            android_name.append(temp_name)\n        \n    else:\n        android_total_string = ''\n        for i in android_total['Package Name'][j*150:(j+1)*150]:\n            android_total_string+=i+','\n            android_total_string = android_total_string[:-1]\n            temp_name = Packageid2AAid('google-play',android_total_string)\n            android_name.append(temp_name)\n\n"

# %%
# 待测试（仅跑前320个）
android_name = pd.DataFrame()
for j in range((320//150)+1):
    print(j)
    if j > 2:
        android_total_string = ''
        for i in android_total['Package Name'][2*150:]:
            android_total_string+=i+','
            android_total_string = android_total_string[:-1]
            temp_name = Packageid2AAid('google-play',android_total_string)
            android_name.append(temp_name)
        
    else:
        android_total_string = ''
        for i in android_total['Package Name'][j*150:(j+1)*150]:
            android_total_string+=i+','
            android_total_string = android_total_string[:-1]
            temp_name = Packageid2AAid('google-play',android_total_string)
            android_name.append(temp_name)
android_name
# Out:
# 0

# %%
android_name

# %%
android_total_string = ''
for i in android_total['Package Name'][:100]:
    android_total_string+=i+','
android_total_string = android_total_string[:-1]

# %%
android_name = Packageid2AAid('google-play',android_total_string)
android_name
# Out:
#                          package_code      product_id
# 0           com.gma.water.sort.puzzle  20600013435453
# 1             com.RBSSOFT.HyperMobile  20600014112565
# 2                       race.arena.io  20600014000752
# 3              com.Celltop.SpiralRoll  20600013134953
# 4             com.fungames.blockcraft  20600006034476
# ..                                ...             ...
# 95              com.kwalee.letsbecops  20600014076224
# 96            com.king.candycrushsaga  20600000578686
# 97                   com.isl.stairrun  20600013991208
# 98  com.tilemaster.puzzle.block.match  20600013072405
# 99      puzzle.blockpuzzle.cube.relax  20600012027042
#
# [100 rows x 2 columns]

# %%
android_total_string_100_250 = ''
for i in android_total['Package Name'][100:250]:
    android_total_string_100_250+=i+','
android_total_string_100_250 = android_total_string_100_250[:-1]

# %%
android_name_100_250 = Packageid2AAid('google-play',android_total_string_100_250)
android_name_100_250
# Out:
#                                package_code      product_id
# 0          com.naxeexllc.stickman.superhero  20600011755193
# 1                    com.earwax.clinic.game  20600013932087
# 2                 com.unicostudio.braintest  20600012666273
# 3                    com.romank.drawmasters  20600013691942
# 4    com.bartoogamecompany.ParentingChoices  20600013577669
# ..                                      ...             ...
# 143                   com.onebutton.mrfight  20600013816894
# 144                         com.vip.spinach  20600013834410
# 145                 net.peakgames.toonblast  20600006900867
# 146                   com.maroieqrwlk.unpin  20600012936910
# 147                 com.ew.dino.city.attack  20600013420746
#
# [148 rows x 2 columns]

# %%
android_name = android_name.append(android_name_100_250)
android_name
# Out:
#                   package_code      product_id
# 0    com.gma.water.sort.puzzle  20600013435453
# 1      com.RBSSOFT.HyperMobile  20600014112565
# 2                race.arena.io  20600014000752
# 3       com.Celltop.SpiralRoll  20600013134953
# 4      com.fungames.blockcraft  20600006034476
# ..                         ...             ...
# 143      com.onebutton.mrfight  20600013816894
# 144            com.vip.spinach  20600013834410
# 145    net.peakgames.toonblast  20600006900867
# 146      com.maroieqrwlk.unpin  20600012936910
# 147    com.ew.dino.city.attack  20600013420746
#
# [396 rows x 2 columns]
